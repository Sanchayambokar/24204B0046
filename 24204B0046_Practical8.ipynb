# %% [markdown]
# 1. Program using math functions
# Power, ceiling, square root, factorial

# %%
import math

n = int(input("Enter a number: "))

print("Power (n^2):", math.pow(n, 2))
print("Ceiling:", math.ceil(n))
print("Square Root:", math.sqrt(n))
print("Factorial:", math.factorial(n))
# Out:
# Enter a number:  16
# Power (n^2): 256.0
# Ceiling: 16
# Square Root: 4.0
# Factorial: 20922789888000

# %% [markdown]
# 2. Program using string functions
# Uppercase , lowercase, replace, find, concatination

# %%
text1 = input("Enter a string: ")
text2 = input("Enter another string: ")

print("Uppercase:", text1.upper())
print("Lowercase:", text1.lower())
print("Replaced String:", text1.replace("a", "@"))
print("Find position:", text1.find("a"))
print("Concatenation:", text1 + " " + text2)
# Out:
# Enter a string: Java
# Enter another string: Programming
# Uppercase: JAVA
# Lowercase: java
# Replaced String: J@v@
# Find position: 1
# Concatenation: Java Programming

# %% [markdown]
# 3. Program for Half Adder and Full Adder using functions

# %%
def half_adder(a, b):
    sum_bit = a ^ b
    carry = a & b
    print("Half Adder -> Sum:", sum_bit, "Carry:", carry)

def full_adder(a, b, cin):
    sum_bit = a ^ b ^ cin
    carry = (a & b) | (b & cin) | (a & cin)
    print("Full Adder -> Sum:", sum_bit, "Carry:", carry)

a = int(input("Enter first bit (0 or 1): "))
b = int(input("Enter second bit (0 or 1): "))

half_adder(a, b)

cin = int(input("Enter carry in (0 or 1): "))
full_adder(a, b, cin)
# Out:
# Enter first bit (0 or 1):  0
# Enter second bit (0 or 1):  1
# Half Adder -> Sum: 1 Carry: 0
# Enter carry in (0 or 1):  1
# Full Adder -> Sum: 0 Carry: 1

# %% [markdown]
# 4. Write a Python script that uses find() function to search for the “language” string from the original string "Python is a powerful language" and returns its index in the Python string.

# %%
text = "Python is a powerful language"

index = text.find("language")

print("Index of 'language':", index)
# Out:
# Index of 'language': 21

# %%
import math
print(math.sqrt(25))
# Out:
# 5.0

# %%
def add(a, b):
    return a + b

print(add(5, 3))
# Out:
# 8
