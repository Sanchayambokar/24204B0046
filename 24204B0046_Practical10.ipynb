# %% [markdown]
# 1. Write a Python script to calculate the DC output voltage(Vdc) of Half wave rectifier using Formula: Vdc=(Vm/π) where Vm is the peak value of output voltage using math module

# %%
import math

Vm = float(input("Enter peak voltage (Vm): "))

Vdc = Vm / math.pi

print("DC Output Voltage (Vdc) =", Vdc)
# Out:
# Enter peak voltage (Vm): 5
# DC Output Voltage (Vdc) = 1.5915494309189535

# %% [markdown]
# 2. Write a Python Script by using statistics module to calculate mean (average value), median (middle value), mode (most often value), standard deviation (spread of values).

# %%
import statistics

data = list(map(float, input("Enter numbers separated by space: ").split()))

mean_value = statistics.mean(data)
median_value = statistics.median(data)
mode_value = statistics.mode(data)
std_dev = statistics.stdev(data)

print("Mean:", mean_value)
print("Median:", median_value)
print("Mode:", mode_value)
print("Standard Deviation:", std_dev)
# Out:
# Enter numbers separated by space: 11 13 10 7 5
# Mean: 9.2
# Median: 10.0
# Mode: 11.0
# Standard Deviation: 3.1937438845342623

# %% [markdown]
# 3. Program to create and use a user-defined calculator module
# Step 1 — Create module: calculator.py
# Import and use calculator module

# %%
class calculator:
    def add(a, b):
        return a + b

    def subtract(a, b):
        return a - b

    def multiply(a, b):
        return a * b

    def divide(a, b):
        return a / b


a = float(input("Enter first number: "))
b = float(input("Enter second number: "))

print("Addition:", calculator.add(a, b))
print("Subtraction:", calculator.subtract(a, b))
print("Multiplication:", calculator.multiply(a, b))
print("Division:", calculator.divide(a, b))
# Out:
# Enter first number:  16
# Enter second number:  04
# Addition: 20.0
# Subtraction: 12.0
# Multiplication: 64.0
# Division: 4.0

# %%
import math
print(math.sqrt(16))
# Out:
# 4.0

# %%
import calculator
print(calculator.add(5, 3))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-227343327.py in <cell line: 0>()
# ----> 1 import calculator
#       2 print(calculator.add(5, 3))
#
# ModuleNotFoundError: No module named 'calculator'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
