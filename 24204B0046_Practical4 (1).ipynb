# %% [markdown]
# Print Name & Roll no

# %%
print("Name: Sanchay Ambokar | Roll No: 24204B0046")
# Out:
# Name: Sanchay Ambokar | Roll No: 24204B0046

# %% [markdown]
# Develop python program to perform following operations on List:
# a) Create
# b) Access
# c) Update
# d) Delete elements from list

# %%
## marks = []

while True:
    print("\n--- Student Management System ---")
    print("1. Enter student marks")
    print("2. Display all marks")
    print("3. Total and Average marks")
    print("4. Highest and Lowest marks")
    print("5. Passed and Failed students")
    print("6. Distinction students (>=75)")
    print("7. Remove duplicate marks")
    print("8. Replace failed marks with grace (40)")
    print("9. Search a mark")
    print("10. Sort marks & reverse")
    print("11. Remove a student record")
    print("12. Find position of a mark")
    print("13. Exit")

    choice = int(input("Enter your choice: "))

    if choice == 1:
        n = int(input("How many students? "))
        for i in range(n):
            m = int(input("Enter mark: "))
            marks.append(m)

    elif choice == 2:
        print("Student Marks:", marks)

    elif choice == 3:
        if len(marks) > 0:
            total = sum(marks)
            avg = total / len(marks)
            print("Total =", total)
            print("Average =", avg)
        else:
            print("No marks available")

    elif choice == 4:
        if len(marks) > 0:
            print("Highest =", max(marks))
            print("Lowest =", min(marks))
        else:
            print("No marks available")

    elif choice == 5:
        passed = []
        failed = []
        for m in marks:
            if m >= 40:
                passed.append(m)
            else:
                failed.append(m)
        print("Passed students:", passed)
        print("Failed students:", failed)

    elif choice == 6:
        distinction = []
        for m in marks:
            if m >= 75:
                distinction.append(m)
        print("Distinction students:", distinction)

    elif choice == 7:
        marks = list(set(marks))
        print("Duplicates removed:", marks)

    elif choice == 8:
        for i in range(len(marks)):
            if marks[i] < 40:
                marks[i] = 40
        print("Grace marks applied:", marks)

    elif choice == 9:
        s = int(input("Enter mark to search: "))
        if s in marks:
            print("Mark found")
        else:
            print("Mark not found")

    elif choice == 10:
        marks.sort()
        print("Sorted marks:", marks)
        print("Reverse order:", marks[::-1])

    elif choice == 11:
        r = int(input("Enter mark to remove: "))
        if r in marks:
            marks.remove(r)
            print("Record removed")
        else:
            print("Mark not found")

    elif choice == 12:
        p = int(input("Enter mark: "))
        if p in marks:
            print("Position (index):", marks.index(p))
        else:
            print("Mark not found")

    elif choice == 13:
        print("Exiting program...")
        break

    else:
        print("Invalid choice")
# Out:
# --- Student Management System ---
# 1. Enter student marks
# 2. Display all marks
# 3. Total and Average marks
# 4. Highest and Lowest marks
# 5. Passed and Failed students
# 6. Distinction students (>=75)
# 7. Remove duplicate marks
# 8. Replace failed marks with grace (40)
# 9. Search a mark
# 10. Sort marks & reverse
# 11. Remove a student record
# 12. Find position of a mark
# 13. Exit
# Enter your choice:  1
# How many students?  1
# Enter mark:  78
# --- Student Management System ---
# 1. Enter student marks
# 2. Display all marks
# 3. Total and Average marks
# 4. Highest and Lowest marks
# 5. Passed and Failed students
# 6. Distinction students (>=75)
# 7. Remove duplicate marks
# 8. Replace failed marks with grace (40)
# 9. Search a mark
# 10. Sort marks & reverse
# 11. Remove a student record
# 12. Find position of a mark
# 13. Exit
# Enter your choice:  2
# Student Marks: [78]
#
# --- Student Management System ---
# 1. Enter student marks
# 2. Display all marks
# 3. Total and Average marks
# 4. Highest and Lowest marks
# 5. Passed and Failed students
# 6. Distinction students (>=75)
# 7. Remove duplicate marks
# 8. Replace failed marks with grace (40)
# 9. Search a mark
# 10. Sort marks & reverse
# 11. Remove a student record
# 12. Find position of a mark
# 13. Exit
# Enter your choice:  3
# Total = 78
# Average = 78.0
#
# --- Student Management System ---
# 1. Enter student marks
# 2. Display all marks
# 3. Total and Average marks
# 4. Highest and Lowest marks
# 5. Passed and Failed students
# 6. Distinction students (>=75)
# 7. Remove duplicate marks
# 8. Replace failed marks with grace (40)
# 9. Search a mark
# 10. Sort marks & reverse
# 11. Remove a student record
# 12. Find position of a mark
# 13. Exit
# Enter your choice:  4
# Highest = 78
# Lowest = 78
#
# --- Student Management System ---
# 1. Enter student marks
# 2. Display all marks
# 3. Total and Average marks
# 4. Highest and Lowest marks
# 5. Passed and Failed students
# 6. Distinction students (>=75)
# 7. Remove duplicate marks
# 8. Replace failed marks with grace (40)
# 9. Search a mark
# 10. Sort marks & reverse
# 11. Remove a student record
# 12. Find position of a mark
# 13. Exit
# Enter your choice:  5
# Passed students: [78]
# Failed students: []
#
# --- Student Management System ---
# 1. Enter student marks
# 2. Display all marks
# 3. Total and Average marks
# 4. Highest and Lowest marks
# 5. Passed and Failed students
# 6. Distinction students (>=75)
# 7. Remove duplicate marks
# 8. Replace failed marks with grace (40)
# 9. Search a mark
# 10. Sort marks & reverse
# 11. Remove a student record
# 12. Find position of a mark
# 13. Exit
# Enter your choice:  6
# Distinction students: [78]
#
# --- Student Management System ---
# 1. Enter student marks
# 2. Display all marks
# 3. Total and Average marks
# 4. Highest and Lowest marks
# 5. Passed and Failed students
# 6. Distinction students (>=75)
# 7. Remove duplicate marks
# 8. Replace failed marks with grace (40)
# 9. Search a mark
# 10. Sort marks & reverse
# 11. Remove a student record
# 12. Find position of a mark
# 13. Exit
# Enter your choice:  7
# Duplicates removed: [78]
#
# --- Student Management System ---
# 1. Enter student marks
# 2. Display all marks
# 3. Total and Average marks
# 4. Highest and Lowest marks
# 5. Passed and Failed students
# 6. Distinction students (>=75)
# 7. Remove duplicate marks
# 8. Replace failed marks with grace (40)
# 9. Search a mark
# 10. Sort marks & reverse
# 11. Remove a student record
# 12. Find position of a mark
# 13. Exit
# Enter your choice:  8
# Grace marks applied: [78]
#
# --- Student Management System ---
# 1. Enter student marks
# 2. Display all marks
# 3. Total and Average marks
# 4. Highest and Lowest marks
# 5. Passed and Failed students
# 6. Distinction students (>=75)
# 7. Remove duplicate marks
# 8. Replace failed marks with grace (40)
# 9. Search a mark
# 10. Sort marks & reverse
# 11. Remove a student record
# 12. Find position of a mark
# 13. Exit
# Enter your choice:  9
# Enter mark to search:  78
# Mark found
#
# --- Student Management System ---
# 1. Enter student marks
# 2. Display all marks
# 3. Total and Average marks
# 4. Highest and Lowest marks
# 5. Passed and Failed students
# 6. Distinction students (>=75)
# 7. Remove duplicate marks
# 8. Replace failed marks with grace (40)
# 9. Search a mark
# 10. Sort marks & reverse
# 11. Remove a student record
# 12. Find position of a mark
# 13. Exit
# Enter your choice:  10
# Sorted marks: [78]
# Reverse order: [78]
#
# --- Student Management System ---
# 1. Enter student marks
# 2. Display all marks
# 3. Total and Average marks
# 4. Highest and Lowest marks
# 5. Passed and Failed students
# 6. Distinction students (>=75)
# 7. Remove duplicate marks
# 8. Replace failed marks with grace (40)
# 9. Search a mark
# 10. Sort marks & reverse
# 11. Remove a student record
# 12. Find position of a mark
# 13. Exit
# Enter your choice:  11
# Enter mark to remove:  78
# Record removed
#
# --- Student Management System ---
# 1. Enter student marks
# 2. Display all marks
# 3. Total and Average marks
# 4. Highest and Lowest marks
# 5. Passed and Failed students
# 6. Distinction students (>=75)
# 7. Remove duplicate marks
# 8. Replace failed marks with grace (40)
# 9. Search a mark
# 10. Sort marks & reverse
# 11. Remove a student record
# 12. Find position of a mark
# 13. Exit
# Enter your choice:  12
# Enter mark:  78
# Mark not found
#
# --- Student Management System ---
# 1. Enter student marks
# 2. Display all marks
# 3. Total and Average marks
# 4. Highest and Lowest marks
# 5. Passed and Failed students
# 6. Distinction students (>=75)
# 7. Remove duplicate marks
# 8. Replace failed marks with grace (40)
# 9. Search a mark
# 10. Sort marks & reverse
# 11. Remove a student record
# 12. Find position of a mark
# 13. Exit
# Enter your choice:  13
# Exiting program...

# %%
lst = [1, 2, 3]
print(lst[-1])
# Out:
# 3

# %%
lst = [10, 20, 30]
lst[1] = 25
print(lst)
# Out:
# [10, 25, 30]
