# %% [markdown]
# 1. Program to create a Student class and display details

# %%
class Student:
    def __init__(self, name, age, course):
        self.name = name
        self.age = age
        self.course = course

    def display(self):
        print("Name:", self.name)
        print("Age:", self.age)
        print("Course:", self.course)

s1 = Student("Sanchay Ambokar", 18, "Electronics and Computer Enginnering")
s1.display()
# Out:
# Name: Sanchay Ambokar
# Age: 18
# Course: Electronics and Computer Enginnering

# %% [markdown]
# 2. Program using constructor to initialize student details

# %%
class Student:
    def __init__(self, name, age, marks):
        self.name = name
        self.age = age
        self.marks = marks

    def display(self):
        print("Name:", self.name)
        print("Age:", self.age)
        print("Marks:", self.marks)

s1 = Student("Sanchay", 18, 97)
s1.display()
# Out:
# Name: Sanchay
# Age: 18
# Marks: 97

# %% [markdown]
# 3. Program to take multiple student objects

# %%
class Student:
    def __init__(self, name, age, course):
        self.name = name
        self.age = age
        self.course = course

    def display(self):
        print("Name:", self.name)
        print("Age:", self.age)
        print("Course:", self.course)
        print()

students = []

n = int(input("Enter number of students: "))

for i in range(n):
    name = input("Enter name: ")
    age = int(input("Enter age: "))
    course = input("Enter course: ")
    students.append(Student(name, age, course))

for s in students:
    s.display()
# Out:
# Enter number of students: 2
# Enter name: Sanchay
# Enter age: 18
# Enter course: TE
# Enter name: Aman
# Enter age: 18
# Enter course: TE
# Name: Sanchay
# Age: 18
# Course: TE
#
# Name: Aman
# Age: 18
# Course: TE

# %%
class Student:
    def __init__(self):
        self.name = "Amit"

s1 = Student()
print(s1.name)
# Out:
# Amit

# %%
class Student:
    def show(self):
        print("Hello")

obj = Student()
obj.show()
# Out:
# Hello
